# %% [markdown]
# # Testing notebook for m1

# %%
from src.openfema.utils.ids import *

# %%
load_id = new_load_id()
date = utc_ingest_date()
ts = utc_now_ts()

print(f"load_id: {load_id}")
print(f"date: {date}")
print(f"time stamp: {ts}")
