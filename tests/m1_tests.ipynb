# %% [markdown]
# # Testing notebook for m1

# %% [markdown]
# ## Installing & Restart

# %%
# %pip install -r ../requirements.txt
dbutils.library.restartPython()

# %% [markdown]
# ## Imports

# %%
import os
from pathlib import Path
from src.openfema.utils.ids import new_load_id, utc_ingest_date, utc_now_ts

# %% [markdown]
# ## Utils check

# %%
load_id = new_load_id()
date = utc_ingest_date()
ts = utc_now_ts()

print(f"load_id: {load_id}")
print(f"date: {date}")
print(f"time stamp: {ts}")

# %% [markdown]
# ## dlt configs check

# %%
# Going to the root
REPO_ROOT = Path.cwd().resolve().parents[0]
DLT_PROJECT_DIR = REPO_ROOT / "configs"
os.environ["DLT_PROJECT_DIR"] = str(DLT_PROJECT_DIR)

# %%
import dlt
#Check if we are reading correctly config

bucket_url = dlt.config.get("destination.filesystem.bucket_url", str)
print(f"Bucket URL: {bucket_url}")

base_url = dlt.config.get("sources.openfema.configs.base_url", str)
pipeline_name = dlt.config.get("sources.openfema.configs.pipeline_name", str)

print(f"\nOther configs:")
print(f"Base URL: {base_url}")
print(f"Pipeline Name: {pipeline_name}")
